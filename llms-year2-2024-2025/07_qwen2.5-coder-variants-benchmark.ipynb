# %% [markdown]
# # Qwen 2.5-coder variants benchmark

# %% [markdown]
# ## ollama setup
#
# https://aider.chat/2024/11/21/quantization.html#setting-ollamas-context-window-size
#
# cd /workspace/wordslab-llms/ollama/bin
#
# OLLAMA_HOST=0.0.0.0 ./ollama serve
#
# ./ollama pull qwen2.5-coder:7b
#
# ./ollama show qwen2.5-coder:7b --modelfile > settings.txt
#
# vi settings.txt ## Add PARAMETER num_ctx 8192 at the end of the file
#
# ./ollama create qwen2.5-coder:7b-8k -f settings.txt
#
# ## ollama tested models
#
# ./ollama pull qwen2.5-coder:7b
#
# NAME                   ID              SIZE      PROCESSOR
# qwen2.5-coder:7b-8k    ac3fb70aa735    8.9 GB    100% GPU
#
# ./ollama pull qwen2.5-coder:7b-instruct-q8_0
#
# NAME                        ID              SIZE     PROCESSOR
# qwen2.5-coder:7b-int8-8k    38b50b1d0e8e    12 GB    100% GPU
#
# ./ollama pull qwen2.5-coder:7b-instruct-fp16
#
# NAME                        ID              SIZE     PROCESSOR
# qwen2.5-coder:7b-fp16-8k    9e0d8452b05d    18 GB
#
# ./ollama pull hf.co/bartowski/Qwen2.5.1-Coder-7B-Instruct-GGUF:Q8_0
#
# NAME                                  ID              SIZE     PROCESSOR
# qwen2.5-coder:7b-bartowski-int8-8k    276ce9838f83    12 GB    100% GPU
#
# ./ollama pull hf.co/bartowski/Qwen2.5.1-Coder-7B-Instruct-GGUF:Q4_K_L
#
# NAME                             ID              SIZE      PROCESSOR
# qwen2.5-coder:7b-bartowski-8k    2dc6eb25931d    8.9 GB    100% GPU
#
# ./ollama pull qwen2.5-coder:14b
#
# NAME                    ID              SIZE     PROCESSOR
# qwen2.5-coder:14b-8k    e0f25a5f2c0a    18 GB    100% GPU
#
# ./ollama pull qwen2.5-coder:14b-instruct-q8_0
#
# NAME                         ID              SIZE     PROCESSOR    UNTIL
# qwen2.5-coder:14b-int8-8k    6032005c5055    17 GB    100% GPU
#
# ./ollama pull qwen2.5-coder:32b
#
# NAME                    ID              SIZE     PROCESSOR    UNTIL
# qwen2.5-coder:32b-8k    4eebfffe9e88    23 GB    100% GPU
#
# ./ollama pull hf.co/bartowski/Qwen2.5-Coder-14B-Instruct-GGUF:Q4_K_M
#
# NAME                              ID              SIZE     PROCESSOR    UNTIL
# qwen2.5-coder:14b-bartowski-8k    11490802f65b    18 GB    100% GPU
#
# ./ollama pull hf.co/bartowski/Qwen2.5-Coder-32B-Instruct-GGUF:Q4_K_S
#
#
# ## aider benchmark setup
#
# https://github.com/Aider-AI/aider/blob/main/benchmark/README.md
#
# ### build container
#
# create-workspace-project https://github.com/Aider-AI/aider.git
#
# cd /workspace/aider
# mkdir tmp.benchmarks
# git clone https://github.com/exercism/python.git
# cp -rp python/exercises/practice tmp.benchmarks/exercism-python
#
# service docker start
# ./benchmark/docker_build.sh
#
# vi ## Add env variable -e OLLAMA_API_BASE=http://host.docker.internal:11434 instead of OPENAI key
#
# ### run benchmark
#
# ./benchmark/docker.sh
#
# ./benchmark/benchmark.py --new qwen2.5-coder-7b-8k-whole --model ollama_chat/qwen2.5-coder:7b-8k --edit-format whole
#
# ### aider reference results
#
# https://github.com/Aider-AI/aider/blob/main/aider/website/_data/quant.yml

# %% [markdown]
# ## Results with the recommended 8k ollama context length
#
# Note: for 7B / int4, the diff format benchmark freezed two times (entered an endless loop ?).
#
# ```
# - dirname: 2024-11-30-15-38-47--qwen2.5-coder-7b-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:7b-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 48.1
#   pass_rate_2: 52.6
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 2
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 2
#   command: aider --model ollama_chat/qwen2.5-coder:7b-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 7.4
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-17-16-20--qwen2.5-coder-7b-int8-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:7b-int8-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 47.4
#   pass_rate_2: 56.4
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 8
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 3
#   command: aider --model ollama_chat/qwen2.5-coder:7b-int8-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 11.3
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-17-47-28--qwen2.5-coder-7b-fp16-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:7b-fp16-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 46.6
#   pass_rate_2: 56.4
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 10
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 2
#   command: aider --model ollama_chat/qwen2.5-coder:7b-fp16-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 16.2
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-21-50-48--qwen2.5-coder:7b-bartowski-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:7b-bartowski-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 53.4
#   pass_rate_2: 61.7
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 2
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 1
#   command: aider --model ollama_chat/qwen2.5-coder:7b-bartowski-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 7.4
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-20-25-15--qwen2.5-coder-7b-bartowski-int8-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:7b-bartowski-int8-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 54.1
#   pass_rate_2: 63.9
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 3
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 1
#   command: aider --model ollama_chat/qwen2.5-coder:7b-bartowski-int8-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 10.1
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-21-00-05--qwen2.5-coder-14b-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:14b-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 53.4
#   pass_rate_2: 68.4
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 6
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 2
#   command: aider --model ollama_chat/qwen2.5-coder:14b-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 14.5
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-22-19-01--qwen2.5-coder-14b-int8-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:14b-int8-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 57.9
#   pass_rate_2: 71.4
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 8
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 2
#   exhausted_context_windows: 0
#   test_timeouts: 1
#   command: aider --model ollama_chat/qwen2.5-coder:14b-int8-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 15.3
#   total_cost: 0.0000
#
# - dirname: 2024-12-01-09-46-02--qwen2.5-coder-14b-bartowski-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:14b-bartowski-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 54.9
#   pass_rate_2: 68.4
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 3
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 0
#   command: aider --model ollama_chat/qwen2.5-coder:14b-bartowski-8k
#   date: 2024-12-01
#   versions: 0.65.2.dev
#   seconds_per_case: 12.6
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-23-01-05--qwen2.5-coder-32b-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:32b-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 57.9
#   pass_rate_2: 72.9
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 9
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 1
#   command: aider --model ollama_chat/qwen2.5-coder:32b-8k
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 60.1
#   total_cost: 0.0000
#
# - dirname: 2024-12-01-15-33-26--llama3.1-8b-int8-8k-whole
#   test_cases: 133
#   model: ollama_chat/llama3.1:8b-int8-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 23.3
#   pass_rate_2: 33.8
#   percent_cases_well_formed: 99.2
#   error_outputs: 1
#   num_malformed_responses: 1
#   num_with_malformed_responses: 1
#   user_asks: 61
#   lazy_comments: 7
#   syntax_errors: 2
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 4
#   command: aider --model ollama_chat/llama3.1:8b-int8-8k
#   date: 2024-12-01
#   versions: 0.65.2.dev
#   seconds_per_case: 31.4
#   total_cost: 0.0000
#
# - dirname: 2024-12-01-18-36-38--qwen2.5-coder-32b-bartowski-8k-whole
#   test_cases: 89
#   model: ollama_chat/qwen2.5-coder:32b-bartowski-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 58.4
#   pass_rate_2: 71.9
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 0
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 1
#   command: aider --model ollama_chat/qwen2.5-coder:32b-bartowski-8k
#   date: 2024-12-01
#   versions: 0.65.2.dev
#   seconds_per_case: 18.8
#   total_cost: 0.0000
#
# - dirname: 2024-12-01-19-28-22--qwen2.5-coder-14b-bartowski-int6-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:14b-bartowski-int6-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 58.6
#   pass_rate_2: 68.4
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 8
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 1
#   exhausted_context_windows: 0
#   test_timeouts: 1
#   command: aider --model ollama_chat/qwen2.5-coder:14b-bartowski-int6-8k
#   date: 2024-12-01
#   versions: 0.65.2.dev
#   seconds_per_case: 15.2
#   total_cost: 0.0000
#
# costs: $0.0000/test-case, $0.00 total, $0.00 projected
#
# - dirname: 2024-12-01-20-19-23--qwen2.5-coder-32b-bartowski-8k-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:32b-bartowski-8k
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 59.4
#   pass_rate_2: 72.2
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 0
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 2
#   command: aider --model ollama_chat/qwen2.5-coder:32b-bartowski-8k
#   date: 2024-12-01
#   versions: 0.65.2.dev
#   seconds_per_case: 93.5
#   total_cost: 0.0000
# ```

# %% [markdown]
# ##  Results with the default 2k ollama context length
#
# ```
# - dirname: 2024-11-30-13-13-48--qwen2.5-coder-7b-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:7b
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 44.4
#   pass_rate_2: 48.9
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 12
#   lazy_comments: 3
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 4
#   command: aider --model ollama_chat/qwen2.5-coder:7b
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 7.1
#   total_cost: 0.0000
#
# - dirname: 2024-11-30-13-42-28--qwen2.5-coder-14b-whole
#   test_cases: 133
#   model: ollama_chat/qwen2.5-coder:14b
#   edit_format: whole
#   commit_hash: 2c7251f-dirty
#   pass_rate_1: 52.6
#   pass_rate_2: 64.7
#   percent_cases_well_formed: 100.0
#   error_outputs: 0
#   num_malformed_responses: 0
#   num_with_malformed_responses: 0
#   user_asks: 22
#   lazy_comments: 0
#   syntax_errors: 0
#   indentation_errors: 0
#   exhausted_context_windows: 0
#   test_timeouts: 2
#   command: aider --model ollama_chat/qwen2.5-coder:14b
#   date: 2024-11-30
#   versions: 0.65.2.dev
#   seconds_per_case: 12.7
#   total_cost: 0.0000
# ```
